# %% [markdown]
# # Exercise: generate histograms of gene lengths
# **Task**: Download GFF files of *Staphylococcus aureus*, *Salmonella* Typhimurium and *Escherichia coli* and create one histogram of gene lengths for each species. The code should not contain redundant elements and should be reusable.

# %% [markdown]
# Starting help:

# %%
gff_files_and_source_urls = {"S_aureus.gff.gz" : "ftp://ftp.ncbi.nlm.nih.gov/genomes/all/GCF/000/013/425/GCF_000013425.1_ASM1342v1/GCF_000013425.1_ASM1342v1_genomic.gff.gz",
                           "S_typhimurium.gff.gz" : "ftp://ftp.ncbi.nlm.nih.gov/genomes/all/GCF/000/195/995/GCF_000195995.1_ASM19599v1/GCF_000195995.1_ASM19599v1_genomic.gff.gz",
                           "E_coli.gff.gz":"ftp://ftp.ncbi.nlm.nih.gov/genomes/refseq/bacteria/Escherichia_coli/reference/GCF_000005845.2_ASM584v2/GCF_000005845.2_ASM584v2_genomic.gff.gz"}

# %%
# plt.show is needed to display more than one plot
import matplotlib.pyplot as plt
plt.show()

# %% [markdown]
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .

# %% [markdown]
# Starting help(2):

# %%
for gff_file, source_url in gff_files_and_source_urls.items():
    print(gff_file)
    print(source_url)

# %% [markdown]
# ## Solution:

# %%
# %matplotlib inline
import urllib.request
import pandas as pd
import matplotlib.pyplot as plt
for gff_file, source_url in gff_files_and_source_urls.items():
    urllib.request.urlretrieve(source_url, gff_file)
    gff_data = pd.read_csv(gff_file, sep="\t", comment="#", 
                       names=["seqid", "source", "type", "start", "end", "score", "strand", "phase", "attributes"])
    gff_data["length"] = gff_data["end"] - gff_data["start"] + 1
    gene_data = gff_data[gff_data["type"] == "gene"]
    gene_data["length"].hist(bins=30, color="black")
    plt.show()

# %% [markdown]
# ## Bonus task: Add the species name to the histogram

# %% [markdown]
# ## Solution:

# %%
# %matplotlib inline
import urllib.request
import pandas as pd
import matplotlib.pyplot as plt
for gff_file, source_url in gff_files_and_source_urls.items():
    urllib.request.urlretrieve(source_url, gff_file)
    gff_data = pd.read_csv(gff_file, sep="\t", comment="#", 
                       names=["seqid", "source", "type", "start", "end", "score", "strand", "phase", "attributes"])
    gff_data["length"] = gff_data["end"] - gff_data["start"]
    gene_data = gff_data[gff_data["type"] == "gene"]
    gene_data["length"].hist(bins=30, color="black")
    plt.show()
    species = gff_file.split(".")[0]
    print(f"gene lengths of {species}")
# Out:
# gene lengths of S_aureus
# gene lengths of S_typhimurium
# gene lengths of E_coli

# %% [markdown]
# ## Bonus task: replace the underscore with a dot and a space

# %% [markdown]
# ## Solution:

# %%
# %matplotlib inline
import urllib.request
import pandas as pd
import matplotlib.pyplot as plt
for gff_file, source_url in gff_files_and_source_urls.items():
    urllib.request.urlretrieve(source_url, gff_file)
    gff_data = pd.read_csv(gff_file, sep="\t", comment="#", 
                       names=["seqid", "source", "type", "start", "end", "score", "strand", "phase", "attributes"])
    gff_data["length"] = gff_data["end"] - gff_data["start"]
    gene_data = gff_data[gff_data["type"] == "gene"]
    gene_data["length"].hist(bins=30, color="black")
    plt.show()
    species = gff_file.split(".")[0].replace("_", ". ")
    print(f"           gene lengths of {species}")
# Out:
#            gene lengths of S. aureus
#            gene lengths of S. typhimurium
#            gene lengths of E. coli
