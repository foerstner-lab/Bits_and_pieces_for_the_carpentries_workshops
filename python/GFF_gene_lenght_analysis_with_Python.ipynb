# %%
import urllib.request
import pandas as pd

# %%
source_url = "ftp://ftp.ncbi.nlm.nih.gov/genomes/refseq/bacteria/Escherichia_coli/reference/GCF_000005845.2_ASM584v2/GCF_000005845.2_ASM584v2_genomic.gff.gz"
gff_file = "E_coli.gff.gz"

# %%
urllib.request.urlretrieve(source_url, gff_file)
# Out:
# ('E_colie.gff.gz', <email.message.Message at 0x7f5f55291278>)

# %%
gff_data = pd.read_csv(gff_file, sep="\t", comment="#", 
                       names=["seqid", "source", "type", "start", "end", "score", "strand", "phase", "attributes"])

# %%
gff_data
# Out:
#              seqid  source           type    start      end score strand  \
# 0      NC_000913.3  RefSeq         region        1  4641652     .      +
# 1      NC_000913.3  RefSeq           gene      190      255     .      +
# 2      NC_000913.3  RefSeq            CDS      190      255     .      +
# 3      NC_000913.3  RefSeq           gene      337     2799     .      +
# 4      NC_000913.3  RefSeq            CDS      337     2799     .      +
# 5      NC_000913.3  RefSeq           gene     2801     3733     .      +
# 6      NC_000913.3  RefSeq            CDS     2801     3733     .      +
# 7      NC_000913.3  RefSeq           gene     3734     5020     .      +
# 8      NC_000913.3  RefSeq            CDS     3734     5020     .      +
# 9      NC_000913.3  RefSeq           gene     5234     5530     .      +
# 10     NC_000913.3  RefSeq            CDS     5234     5530     .      +
# 11     NC_000913.3  RefSeq  repeat_region     5566     5601     .      +
# 12     NC_000913.3  RefSeq  repeat_region     5637     5670     .      -
# 13     NC_000913.3  RefSeq           gene     5683     6459     .      -
# 14     NC_000913.3  RefSeq            CDS     5683     6459     .      -
# 15     NC_000913.3  RefSeq           gene     6529     7959     .      -
# 16     NC_000913.3  RefSeq            CDS     6529     7959     .      -
# 17     NC_000913.3  RefSeq           gene     8238     9191     .      +
# 18     NC_000913.3  RefSeq            CDS     8238     9191     .      +
# 19     NC_000913.3  RefSeq           gene     9306     9893     .      +
# 20     NC_000913.3  RefSeq            CDS     9306     9893     .      +
# 21     NC_000913.3  RefSeq           gene     9928    10494     .      -
# 22     NC_000913.3  RefSeq            CDS     9928    10494     .      -
# 23     NC_000913.3  RefSeq           gene    10643    11356     .      -
# 24     NC_000913.3  RefSeq            CDS    10643    11356     .      -
# 25     NC_000913.3  RefSeq           gene    10830    11315     .      +
# 26     NC_000913.3  RefSeq            CDS    10830    11315     .      +
# 27     NC_000913.3  RefSeq           gene    11382    11786     .      -
# 28     NC_000913.3  RefSeq            CDS    11382    11786     .      -
# 29     NC_000913.3  RefSeq           gene    12163    14079     .      +
# ...            ...     ...            ...      ...      ...   ...    ...
# 10091  NC_000913.3  RefSeq  repeat_region  4628812  4628845     .      -
# 10092  NC_000913.3  RefSeq           gene  4628855  4630522     .      -
# 10093  NC_000913.3  RefSeq            CDS  4628855  4630522     .      -
# 10094  NC_000913.3  RefSeq           gene  4630733  4632670     .      +
# 10095  NC_000913.3  RefSeq            CDS  4630733  4632670     .      +
# 10096  NC_000913.3  RefSeq           gene  4632760  4633086     .      +
# 10097  NC_000913.3  RefSeq            CDS  4632760  4633086     .      +
# 10098  NC_000913.3  RefSeq  repeat_region  4633092  4633128     .      -
# 10099  NC_000913.3  RefSeq  repeat_region  4633136  4633169     .      +
# 10100  NC_000913.3  RefSeq  repeat_region  4633196  4633231     .      -
# 10101  NC_000913.3  RefSeq           gene  4633233  4633745     .      -
# 10102  NC_000913.3  RefSeq            CDS  4633233  4633745     .      -
# 10103  NC_000913.3  RefSeq           gene  4633797  4634444     .      +
# 10104  NC_000913.3  RefSeq            CDS  4633797  4634444     .      +
# 10105  NC_000913.3  RefSeq           gene  4634441  4635310     .      -
# 10106  NC_000913.3  RefSeq            CDS  4634441  4635310     .      -
# 10107  NC_000913.3  RefSeq           gene  4635521  4635994     .      +
# 10108  NC_000913.3  RefSeq            CDS  4635521  4635994     .      +
# 10109  NC_000913.3  RefSeq           gene  4636007  4636696     .      +
# 10110  NC_000913.3  RefSeq            CDS  4636007  4636696     .      +
# 10111  NC_000913.3  RefSeq           gene  4636696  4638120     .      +
# 10112  NC_000913.3  RefSeq            CDS  4636696  4638120     .      +
# 10113  NC_000913.3  RefSeq           gene  4638178  4639530     .      +
# 10114  NC_000913.3  RefSeq            CDS  4638178  4639530     .      +
# 10115  NC_000913.3  RefSeq           gene  4639590  4640306     .      -
# 10116  NC_000913.3  RefSeq            CDS  4639590  4640306     .      -
# 10117  NC_000913.3  RefSeq           gene  4640402  4640542     .      +
# 10118  NC_000913.3  RefSeq            CDS  4640402  4640542     .      +
# 10119  NC_000913.3  RefSeq           gene  4640942  4641628     .      +
# 10120  NC_000913.3  RefSeq            CDS  4640942  4641628     .      +
#
#       phase                                         attributes
# 0         .  ID=NC_000913.3:1..4641652;Dbxref=taxon:511145;...
# 1         .  ID=gene-b0001;Dbxref=ASAP:ABE-0000006,ECOCYC:E...
# 2         0  ID=cds-NP_414542.1;Parent=gene-b0001;Dbxref=Un...
# 3         .  ID=gene-b0002;Dbxref=ASAP:ABE-0000008,ECOCYC:E...
# 4         0  ID=cds-NP_414543.1;Parent=gene-b0002;Dbxref=Un...
# 5         .  ID=gene-b0003;Dbxref=ASAP:ABE-0000010,ECOCYC:E...
# 6         0  ID=cds-NP_414544.1;Parent=gene-b0003;Dbxref=Un...
# 7         .  ID=gene-b0004;Dbxref=ASAP:ABE-0000012,ECOCYC:E...
# 8         0  ID=cds-NP_414545.1;Parent=gene-b0004;Dbxref=Un...
# 9         .  ID=gene-b0005;Dbxref=ASAP:ABE-0000015,ECOCYC:G...
# 10        0  ID=cds-NP_414546.1;Parent=gene-b0005;Dbxref=Un...
# 11        .  ID=id-12;Note=REP1a;gbkey=repeat_region;rpt_ty...
# 12        .  ID=id-13;Note=REP1b;gbkey=repeat_region;rpt_ty...
# 13        .  ID=gene-b0006;Dbxref=ASAP:ABE-0000018,ECOCYC:E...
# 14        0  ID=cds-NP_414547.1;Parent=gene-b0006;Dbxref=Un...
# 15        .  ID=gene-b0007;Dbxref=ASAP:ABE-0000020,ECOCYC:E...
# 16        0  ID=cds-NP_414548.1;Parent=gene-b0007;Dbxref=Un...
# 17        .  ID=gene-b0008;Dbxref=ASAP:ABE-0000027,ECOCYC:E...
# 18        0  ID=cds-NP_414549.1;Parent=gene-b0008;Dbxref=Un...
# 19        .  ID=gene-b0009;Dbxref=ASAP:ABE-0000030,ECOCYC:E...
# 20        0  ID=cds-NP_414550.1;Parent=gene-b0009;Dbxref=Un...
# 21        .  ID=gene-b0010;Dbxref=ASAP:ABE-0000032,ECOCYC:E...
# 22        0  ID=cds-NP_414551.1;Parent=gene-b0010;Dbxref=Un...
# 23        .  ID=gene-b0011;Dbxref=ASAP:ABE-0000037,ECOCYC:G...
# 24        0  ID=cds-NP_414552.1;Parent=gene-b0011;Dbxref=Un...
# 25        .  ID=gene-b0012;Dbxref=ASAP:ABE-0000040,ECOCYC:E...
# 26        0  ID=cds-YP_009518733.1;Parent=gene-b0012;Dbxref...
# 27        .  ID=gene-b0013;Dbxref=ASAP:ABE-0000043,ECOCYC:G...
# 28        0  ID=cds-NP_414554.1;Parent=gene-b0013;Dbxref=Un...
# 29        .  ID=gene-b0014;Dbxref=ASAP:ABE-0000052,ECOCYC:E...
# ...     ...                                                ...
# 10091     .  ID=id-9871;Note=REP354c;gbkey=repeat_region;rp...
# 10092     .  ID=gene-b4391;Dbxref=ASAP:ABE-0014400,ECOCYC:E...
# 10093     0  ID=cds-NP_418808.1;Parent=gene-b4391;Dbxref=Un...
# 10094     .  ID=gene-b4392;Dbxref=ASAP:ABE-0014404,ECOCYC:E...
# 10095     0  ID=cds-NP_418809.4;Parent=gene-b4392;Dbxref=Un...
# 10096     .  ID=gene-b4393;Dbxref=ASAP:ABE-0014408,ECOCYC:E...
# 10097     0  ID=cds-NP_418810.1;Parent=gene-b4393;Dbxref=Un...
# 10098     .  ID=id-9878;Note=REP355a;gbkey=repeat_region;rp...
# 10099     .  ID=id-9879;Note=REP355b;gbkey=repeat_region;rp...
# 10100     .  ID=id-9880;Note=REP355c;gbkey=repeat_region;rp...
# 10101     .  ID=gene-b4394;Dbxref=ASAP:ABE-0014411,ECOCYC:E...
# 10102     0  ID=cds-NP_418811.2;Parent=gene-b4394;Dbxref=Un...
# 10103     .  ID=gene-b4395;Dbxref=ASAP:ABE-0014416,ECOCYC:E...
# 10104     0  ID=cds-NP_418812.1;Parent=gene-b4395;Dbxref=Un...
# 10105     .  ID=gene-b4396;Dbxref=ASAP:ABE-0014420,ECOCYC:E...
# 10106     0  ID=cds-NP_418813.1;Parent=gene-b4396;Dbxref=Un...
# 10107     .  ID=gene-b4397;Dbxref=ASAP:ABE-0014426,ECOCYC:E...
# 10108     0  ID=cds-NP_418814.1;Parent=gene-b4397;Dbxref=Un...
# 10109     .  ID=gene-b4398;Dbxref=ASAP:ABE-0014428,ECOCYC:E...
# 10110     0  ID=cds-NP_418815.1;Parent=gene-b4398;Dbxref=Un...
# 10111     .  ID=gene-b4399;Dbxref=ASAP:ABE-0014430,ECOCYC:E...
# 10112     0  ID=cds-NP_418816.1;Parent=gene-b4399;Dbxref=Un...
# 10113     .  ID=gene-b4400;Dbxref=ASAP:ABE-0014432,ECOCYC:E...
# 10114     0  ID=cds-NP_418817.1;Parent=gene-b4400;Dbxref=Un...
# 10115     .  ID=gene-b4401;Dbxref=ASAP:ABE-0014434,ECOCYC:E...
# 10116     0  ID=cds-NP_418818.1;Parent=gene-b4401;Dbxref=Un...
# 10117     .  ID=gene-b4402;Dbxref=ASAP:ABE-0014437,ECOCYC:G...
# 10118     0  ID=cds-NP_418819.1;Parent=gene-b4402;Dbxref=Un...
# 10119     .  ID=gene-b4403;Dbxref=ASAP:ABE-0014442,ECOCYC:E...
# 10120     0  ID=cds-NP_418820.1;Parent=gene-b4403;Dbxref=Un...
#
# [10121 rows x 9 columns]

# %%
gff_data.shape
# Out:
# (10121, 9)

# %%
gff_data["type"].unique()
# Out:
# array(['region', 'gene', 'CDS', 'repeat_region', 'mobile_genetic_element',
#        'ncRNA', 'exon', 'rRNA', 'tRNA', 'pseudogene', 'sequence_feature',
#        'recombination_feature', 'origin_of_replication'], dtype=object)

# %%
gff_data[gff_data["type"] == "gene"]
# Out:
#              seqid  source  type    start      end score strand phase  \
# 1      NC_000913.3  RefSeq  gene      190      255     .      +     .
# 3      NC_000913.3  RefSeq  gene      337     2799     .      +     .
# 5      NC_000913.3  RefSeq  gene     2801     3733     .      +     .
# 7      NC_000913.3  RefSeq  gene     3734     5020     .      +     .
# 9      NC_000913.3  RefSeq  gene     5234     5530     .      +     .
# 13     NC_000913.3  RefSeq  gene     5683     6459     .      -     .
# 15     NC_000913.3  RefSeq  gene     6529     7959     .      -     .
# 17     NC_000913.3  RefSeq  gene     8238     9191     .      +     .
# 19     NC_000913.3  RefSeq  gene     9306     9893     .      +     .
# 21     NC_000913.3  RefSeq  gene     9928    10494     .      -     .
# 23     NC_000913.3  RefSeq  gene    10643    11356     .      -     .
# 25     NC_000913.3  RefSeq  gene    10830    11315     .      +     .
# 27     NC_000913.3  RefSeq  gene    11382    11786     .      -     .
# 29     NC_000913.3  RefSeq  gene    12163    14079     .      +     .
# 31     NC_000913.3  RefSeq  gene    14168    15298     .      +     .
# 34     NC_000913.3  RefSeq  gene    15445    16557     .      +     .
# 36     NC_000913.3  RefSeq  gene    16751    16960     .      -     .
# 38     NC_000913.3  RefSeq  gene    16751    16903     .      -     .
# 40     NC_000913.3  RefSeq  gene    16952    17006     .      +     .
# 43     NC_000913.3  RefSeq  gene    17489    18655     .      +     .
# 45     NC_000913.3  RefSeq  gene    18715    19620     .      +     .
# 48     NC_000913.3  RefSeq  gene    19811    20314     .      -     .
# 50     NC_000913.3  RefSeq  gene    20233    20508     .      -     .
# 52     NC_000913.3  RefSeq  gene    20815    21078     .      -     .
# 54     NC_000913.3  RefSeq  gene    21181    21399     .      +     .
# 56     NC_000913.3  RefSeq  gene    21407    22348     .      +     .
# 58     NC_000913.3  RefSeq  gene    22391    25207     .      +     .
# 60     NC_000913.3  RefSeq  gene    25207    25701     .      +     .
# 64     NC_000913.3  RefSeq  gene    25826    26275     .      +     .
# 66     NC_000913.3  RefSeq  gene    26277    27227     .      +     .
# ...            ...     ...   ...      ...      ...   ...    ...   ...
# 10045  NC_000913.3  RefSeq  gene  4609414  4611003     .      +     .
# 10047  NC_000913.3  RefSeq  gene  4611396  4612001     .      +     .
# 10049  NC_000913.3  RefSeq  gene  4612128  4612289     .      +     .
# 10051  NC_000913.3  RefSeq  gene  4612411  4613484     .      +     .
# 10053  NC_000913.3  RefSeq  gene  4613481  4614260     .      +     .
# 10063  NC_000913.3  RefSeq  gene  4614680  4615543     .      -     .
# 10065  NC_000913.3  RefSeq  gene  4615515  4617065     .      -     .
# 10067  NC_000913.3  RefSeq  gene  4617323  4618102     .      +     .
# 10071  NC_000913.3  RefSeq  gene  4618229  4619551     .      +     .
# 10073  NC_000913.3  RefSeq  gene  4619603  4620826     .      +     .
# 10075  NC_000913.3  RefSeq  gene  4620883  4621602     .      +     .
# 10077  NC_000913.3  RefSeq  gene  4621769  4623100     .      +     .
# 10079  NC_000913.3  RefSeq  gene  4623101  4624117     .      -     .
# 10081  NC_000913.3  RefSeq  gene  4624145  4624789     .      -     .
# 10083  NC_000913.3  RefSeq  gene  4624895  4625863     .      +     .
# 10085  NC_000913.3  RefSeq  gene  4625912  4627294     .      +     .
# 10087  NC_000913.3  RefSeq  gene  4627315  4628547     .      +     .
# 10092  NC_000913.3  RefSeq  gene  4628855  4630522     .      -     .
# 10094  NC_000913.3  RefSeq  gene  4630733  4632670     .      +     .
# 10096  NC_000913.3  RefSeq  gene  4632760  4633086     .      +     .
# 10101  NC_000913.3  RefSeq  gene  4633233  4633745     .      -     .
# 10103  NC_000913.3  RefSeq  gene  4633797  4634444     .      +     .
# 10105  NC_000913.3  RefSeq  gene  4634441  4635310     .      -     .
# 10107  NC_000913.3  RefSeq  gene  4635521  4635994     .      +     .
# 10109  NC_000913.3  RefSeq  gene  4636007  4636696     .      +     .
# 10111  NC_000913.3  RefSeq  gene  4636696  4638120     .      +     .
# 10113  NC_000913.3  RefSeq  gene  4638178  4639530     .      +     .
# 10115  NC_000913.3  RefSeq  gene  4639590  4640306     .      -     .
# 10117  NC_000913.3  RefSeq  gene  4640402  4640542     .      +     .
# 10119  NC_000913.3  RefSeq  gene  4640942  4641628     .      +     .
#
#                                               attributes
# 1      ID=gene-b0001;Dbxref=ASAP:ABE-0000006,ECOCYC:E...
# 3      ID=gene-b0002;Dbxref=ASAP:ABE-0000008,ECOCYC:E...
# 5      ID=gene-b0003;Dbxref=ASAP:ABE-0000010,ECOCYC:E...
# 7      ID=gene-b0004;Dbxref=ASAP:ABE-0000012,ECOCYC:E...
# 9      ID=gene-b0005;Dbxref=ASAP:ABE-0000015,ECOCYC:G...
# 13     ID=gene-b0006;Dbxref=ASAP:ABE-0000018,ECOCYC:E...
# 15     ID=gene-b0007;Dbxref=ASAP:ABE-0000020,ECOCYC:E...
# 17     ID=gene-b0008;Dbxref=ASAP:ABE-0000027,ECOCYC:E...
# 19     ID=gene-b0009;Dbxref=ASAP:ABE-0000030,ECOCYC:E...
# 21     ID=gene-b0010;Dbxref=ASAP:ABE-0000032,ECOCYC:E...
# 23     ID=gene-b0011;Dbxref=ASAP:ABE-0000037,ECOCYC:G...
# 25     ID=gene-b0012;Dbxref=ASAP:ABE-0000040,ECOCYC:E...
# 27     ID=gene-b0013;Dbxref=ASAP:ABE-0000043,ECOCYC:G...
# 29     ID=gene-b0014;Dbxref=ASAP:ABE-0000052,ECOCYC:E...
# 31     ID=gene-b0015;Dbxref=ASAP:ABE-0000054,ECOCYC:E...
# 34     ID=gene-b0016;Dbxref=ASAP:ABE-0000058,ECOCYC:G...
# 36     ID=gene-b0018;Dbxref=ASAP:ABE-0000064,ECOCYC:E...
# 38     ID=gene-b4412;Dbxref=ASAP:ABE-0047278,ECOCYC:G...
# 40     ID=gene-b4413;Dbxref=ASAP:ABE-0047238,ECOCYC:G...
# 43     ID=gene-b0019;Dbxref=ASAP:ABE-0000068,ECOCYC:E...
# 45     ID=gene-b0020;Dbxref=ASAP:ABE-0000072,ECOCYC:E...
# 48     ID=gene-b0021;Dbxref=ASAP:ABE-0000075,ECOCYC:G...
# 50     ID=gene-b0022;Dbxref=ASAP:ABE-0000078,ECOCYC:G...
# 52     ID=gene-b0023;Dbxref=ASAP:ABE-0000082,ECOCYC:E...
# 54     ID=gene-b0024;Dbxref=ASAP:ABE-0000089,ECOCYC:G...
# 56     ID=gene-b0025;Dbxref=ASAP:ABE-0000091,ECOCYC:E...
# 58     ID=gene-b0026;Dbxref=ASAP:ABE-0000094,ECOCYC:E...
# 60     ID=gene-b0027;Dbxref=ASAP:ABE-0000096,ECOCYC:E...
# 64     ID=gene-b0028;Dbxref=ASAP:ABE-0000101,ECOCYC:E...
# 66     ID=gene-b0029;Dbxref=ASAP:ABE-0000103,ECOCYC:E...
# ...                                                  ...
# 10045  ID=gene-b4375;Dbxref=ASAP:ABE-0014346,ECOCYC:E...
# 10047  ID=gene-b4376;Dbxref=ASAP:ABE-0014348,ECOCYC:E...
# 10049  ID=gene-b4568;Dbxref=ASAP:ABE-0285089,ECOCYC:G...
# 10051  ID=gene-b4377;Dbxref=ASAP:ABE-0014351,ECOCYC:G...
# 10053  ID=gene-b4378;Dbxref=ASAP:ABE-0014356,ECOCYC:G...
# 10063  ID=gene-b4379;Dbxref=ASAP:ABE-0014359,ECOCYC:G...
# 10065  ID=gene-b4380;Dbxref=ASAP:ABE-0014361,ECOCYC:E...
# 10067  ID=gene-b4381;Dbxref=ASAP:ABE-0014371,ECOCYC:E...
# 10071  ID=gene-b4382;Dbxref=ASAP:ABE-0014374,ECOCYC:E...
# 10073  ID=gene-b4383;Dbxref=ASAP:ABE-0014377,ECOCYC:E...
# 10075  ID=gene-b4384;Dbxref=ASAP:ABE-0014379,ECOCYC:E...
# 10077  ID=gene-b4385;Dbxref=ASAP:ABE-0014383,ECOCYC:E...
# 10079  ID=gene-b4386;Dbxref=ASAP:ABE-0014385,ECOCYC:E...
# 10081  ID=gene-b4387;Dbxref=ASAP:ABE-0014387,ECOCYC:E...
# 10083  ID=gene-b4388;Dbxref=ASAP:ABE-0014393,ECOCYC:E...
# 10085  ID=gene-b4389;Dbxref=ASAP:ABE-0014395,ECOCYC:E...
# 10087  ID=gene-b4390;Dbxref=ASAP:ABE-0014397,ECOCYC:E...
# 10092  ID=gene-b4391;Dbxref=ASAP:ABE-0014400,ECOCYC:E...
# 10094  ID=gene-b4392;Dbxref=ASAP:ABE-0014404,ECOCYC:E...
# 10096  ID=gene-b4393;Dbxref=ASAP:ABE-0014408,ECOCYC:E...
# 10101  ID=gene-b4394;Dbxref=ASAP:ABE-0014411,ECOCYC:E...
# 10103  ID=gene-b4395;Dbxref=ASAP:ABE-0014416,ECOCYC:E...
# 10105  ID=gene-b4396;Dbxref=ASAP:ABE-0014420,ECOCYC:E...
# 10107  ID=gene-b4397;Dbxref=ASAP:ABE-0014426,ECOCYC:E...
# 10109  ID=gene-b4398;Dbxref=ASAP:ABE-0014428,ECOCYC:E...
# 10111  ID=gene-b4399;Dbxref=ASAP:ABE-0014430,ECOCYC:E...
# 10113  ID=gene-b4400;Dbxref=ASAP:ABE-0014432,ECOCYC:E...
# 10115  ID=gene-b4401;Dbxref=ASAP:ABE-0014434,ECOCYC:E...
# 10117  ID=gene-b4402;Dbxref=ASAP:ABE-0014437,ECOCYC:G...
# 10119  ID=gene-b4403;Dbxref=ASAP:ABE-0014442,ECOCYC:E...
#
# [4419 rows x 9 columns]

# %%
gff_data[gff_data["strand"] == "+"]
# Out:
#              seqid  source                    type    start      end score  \
# 0      NC_000913.3  RefSeq                  region        1  4641652     .
# 1      NC_000913.3  RefSeq                    gene      190      255     .
# 2      NC_000913.3  RefSeq                     CDS      190      255     .
# 3      NC_000913.3  RefSeq                    gene      337     2799     .
# 4      NC_000913.3  RefSeq                     CDS      337     2799     .
# 5      NC_000913.3  RefSeq                    gene     2801     3733     .
# 6      NC_000913.3  RefSeq                     CDS     2801     3733     .
# 7      NC_000913.3  RefSeq                    gene     3734     5020     .
# 8      NC_000913.3  RefSeq                     CDS     3734     5020     .
# 9      NC_000913.3  RefSeq                    gene     5234     5530     .
# 10     NC_000913.3  RefSeq                     CDS     5234     5530     .
# 11     NC_000913.3  RefSeq           repeat_region     5566     5601     .
# 17     NC_000913.3  RefSeq                    gene     8238     9191     .
# 18     NC_000913.3  RefSeq                     CDS     8238     9191     .
# 19     NC_000913.3  RefSeq                    gene     9306     9893     .
# 20     NC_000913.3  RefSeq                     CDS     9306     9893     .
# 25     NC_000913.3  RefSeq                    gene    10830    11315     .
# 26     NC_000913.3  RefSeq                     CDS    10830    11315     .
# 29     NC_000913.3  RefSeq                    gene    12163    14079     .
# 30     NC_000913.3  RefSeq                     CDS    12163    14079     .
# 31     NC_000913.3  RefSeq                    gene    14168    15298     .
# 32     NC_000913.3  RefSeq                     CDS    14168    15298     .
# 33     NC_000913.3  RefSeq  mobile_genetic_element    15387    16731     .
# 34     NC_000913.3  RefSeq                    gene    15445    16557     .
# 35     NC_000913.3  RefSeq                     CDS    15445    16557     .
# 40     NC_000913.3  RefSeq                    gene    16952    17006     .
# 41     NC_000913.3  RefSeq                   ncRNA    16952    17006     .
# 42     NC_000913.3  RefSeq                    exon    16952    17006     .
# 43     NC_000913.3  RefSeq                    gene    17489    18655     .
# 44     NC_000913.3  RefSeq                     CDS    17489    18655     .
# ...            ...     ...                     ...      ...      ...   ...
# 10075  NC_000913.3  RefSeq                    gene  4620883  4621602     .
# 10076  NC_000913.3  RefSeq                     CDS  4620883  4621602     .
# 10077  NC_000913.3  RefSeq                    gene  4621769  4623100     .
# 10078  NC_000913.3  RefSeq                     CDS  4621769  4623100     .
# 10083  NC_000913.3  RefSeq                    gene  4624895  4625863     .
# 10084  NC_000913.3  RefSeq                     CDS  4624895  4625863     .
# 10085  NC_000913.3  RefSeq                    gene  4625912  4627294     .
# 10086  NC_000913.3  RefSeq                     CDS  4625912  4627294     .
# 10087  NC_000913.3  RefSeq                    gene  4627315  4628547     .
# 10088  NC_000913.3  RefSeq                     CDS  4627315  4628547     .
# 10090  NC_000913.3  RefSeq           repeat_region  4628744  4628780     .
# 10094  NC_000913.3  RefSeq                    gene  4630733  4632670     .
# 10095  NC_000913.3  RefSeq                     CDS  4630733  4632670     .
# 10096  NC_000913.3  RefSeq                    gene  4632760  4633086     .
# 10097  NC_000913.3  RefSeq                     CDS  4632760  4633086     .
# 10099  NC_000913.3  RefSeq           repeat_region  4633136  4633169     .
# 10103  NC_000913.3  RefSeq                    gene  4633797  4634444     .
# 10104  NC_000913.3  RefSeq                     CDS  4633797  4634444     .
# 10107  NC_000913.3  RefSeq                    gene  4635521  4635994     .
# 10108  NC_000913.3  RefSeq                     CDS  4635521  4635994     .
# 10109  NC_000913.3  RefSeq                    gene  4636007  4636696     .
# 10110  NC_000913.3  RefSeq                     CDS  4636007  4636696     .
# 10111  NC_000913.3  RefSeq                    gene  4636696  4638120     .
# 10112  NC_000913.3  RefSeq                     CDS  4636696  4638120     .
# 10113  NC_000913.3  RefSeq                    gene  4638178  4639530     .
# 10114  NC_000913.3  RefSeq                     CDS  4638178  4639530     .
# 10117  NC_000913.3  RefSeq                    gene  4640402  4640542     .
# 10118  NC_000913.3  RefSeq                     CDS  4640402  4640542     .
# 10119  NC_000913.3  RefSeq                    gene  4640942  4641628     .
# 10120  NC_000913.3  RefSeq                     CDS  4640942  4641628     .
#
#       strand phase                                         attributes
# 0          +     .  ID=NC_000913.3:1..4641652;Dbxref=taxon:511145;...
# 1          +     .  ID=gene-b0001;Dbxref=ASAP:ABE-0000006,ECOCYC:E...
# 2          +     0  ID=cds-NP_414542.1;Parent=gene-b0001;Dbxref=Un...
# 3          +     .  ID=gene-b0002;Dbxref=ASAP:ABE-0000008,ECOCYC:E...
# 4          +     0  ID=cds-NP_414543.1;Parent=gene-b0002;Dbxref=Un...
# 5          +     .  ID=gene-b0003;Dbxref=ASAP:ABE-0000010,ECOCYC:E...
# 6          +     0  ID=cds-NP_414544.1;Parent=gene-b0003;Dbxref=Un...
# 7          +     .  ID=gene-b0004;Dbxref=ASAP:ABE-0000012,ECOCYC:E...
# 8          +     0  ID=cds-NP_414545.1;Parent=gene-b0004;Dbxref=Un...
# 9          +     .  ID=gene-b0005;Dbxref=ASAP:ABE-0000015,ECOCYC:G...
# 10         +     0  ID=cds-NP_414546.1;Parent=gene-b0005;Dbxref=Un...
# 11         +     .  ID=id-12;Note=REP1a;gbkey=repeat_region;rpt_ty...
# 17         +     .  ID=gene-b0008;Dbxref=ASAP:ABE-0000027,ECOCYC:E...
# 18         +     0  ID=cds-NP_414549.1;Parent=gene-b0008;Dbxref=Un...
# 19         +     .  ID=gene-b0009;Dbxref=ASAP:ABE-0000030,ECOCYC:E...
# 20         +     0  ID=cds-NP_414550.1;Parent=gene-b0009;Dbxref=Un...
# 25         +     .  ID=gene-b0012;Dbxref=ASAP:ABE-0000040,ECOCYC:E...
# 26         +     0  ID=cds-YP_009518733.1;Parent=gene-b0012;Dbxref...
# 29         +     .  ID=gene-b0014;Dbxref=ASAP:ABE-0000052,ECOCYC:E...
# 30         +     0  ID=cds-NP_414555.1;Parent=gene-b0014;Dbxref=Un...
# 31         +     .  ID=gene-b0015;Dbxref=ASAP:ABE-0000054,ECOCYC:E...
# 32         +     0  ID=cds-NP_414556.1;Parent=gene-b0015;Dbxref=Un...
# 33         +     .  ID=id-34;gbkey=mobile_element;mobile_element_t...
# 34         +     .  ID=gene-b0016;Dbxref=ASAP:ABE-0000058,ECOCYC:G...
# 35         +     0  ID=cds-NP_414557.1;Parent=gene-b0016;Dbxref=Un...
# 40         +     .  ID=gene-b4413;Dbxref=ASAP:ABE-0047238,ECOCYC:G...
# 41         +     .  ID=rna-b4413;Parent=gene-b4413;Dbxref=ASAP:ABE...
# 42         +     .  ID=exon-b4413-1;Parent=rna-b4413;Dbxref=ASAP:A...
# 43         +     .  ID=gene-b0019;Dbxref=ASAP:ABE-0000068,ECOCYC:E...
# 44         +     0  ID=cds-NP_414560.1;Parent=gene-b0019;Dbxref=Un...
# ...      ...   ...                                                ...
# 10075      +     .  ID=gene-b4384;Dbxref=ASAP:ABE-0014379,ECOCYC:E...
# 10076      +     0  ID=cds-NP_418801.1;Parent=gene-b4384;Dbxref=Un...
# 10077      +     .  ID=gene-b4385;Dbxref=ASAP:ABE-0014383,ECOCYC:E...
# 10078      +     0  ID=cds-NP_418802.1;Parent=gene-b4385;Dbxref=Un...
# 10083      +     .  ID=gene-b4388;Dbxref=ASAP:ABE-0014393,ECOCYC:E...
# 10084      +     0  ID=cds-NP_418805.1;Parent=gene-b4388;Dbxref=Un...
# 10085      +     .  ID=gene-b4389;Dbxref=ASAP:ABE-0014395,ECOCYC:E...
# 10086      +     0  ID=cds-NP_418806.1;Parent=gene-b4389;Dbxref=Un...
# 10087      +     .  ID=gene-b4390;Dbxref=ASAP:ABE-0014397,ECOCYC:E...
# 10088      +     0  ID=cds-NP_418807.4;Parent=gene-b4390;Dbxref=Un...
# 10090      +     .  ID=id-9870;Note=REP354b;gbkey=repeat_region;rp...
# 10094      +     .  ID=gene-b4392;Dbxref=ASAP:ABE-0014404,ECOCYC:E...
# 10095      +     0  ID=cds-NP_418809.4;Parent=gene-b4392;Dbxref=Un...
# 10096      +     .  ID=gene-b4393;Dbxref=ASAP:ABE-0014408,ECOCYC:E...
# 10097      +     0  ID=cds-NP_418810.1;Parent=gene-b4393;Dbxref=Un...
# 10099      +     .  ID=id-9879;Note=REP355b;gbkey=repeat_region;rp...
# 10103      +     .  ID=gene-b4395;Dbxref=ASAP:ABE-0014416,ECOCYC:E...
# 10104      +     0  ID=cds-NP_418812.1;Parent=gene-b4395;Dbxref=Un...
# 10107      +     .  ID=gene-b4397;Dbxref=ASAP:ABE-0014426,ECOCYC:E...
# 10108      +     0  ID=cds-NP_418814.1;Parent=gene-b4397;Dbxref=Un...
# 10109      +     .  ID=gene-b4398;Dbxref=ASAP:ABE-0014428,ECOCYC:E...
# 10110      +     0  ID=cds-NP_418815.1;Parent=gene-b4398;Dbxref=Un...
# 10111      +     .  ID=gene-b4399;Dbxref=ASAP:ABE-0014430,ECOCYC:E...
# 10112      +     0  ID=cds-NP_418816.1;Parent=gene-b4399;Dbxref=Un...
# 10113      +     .  ID=gene-b4400;Dbxref=ASAP:ABE-0014432,ECOCYC:E...
# 10114      +     0  ID=cds-NP_418817.1;Parent=gene-b4400;Dbxref=Un...
# 10117      +     .  ID=gene-b4402;Dbxref=ASAP:ABE-0014437,ECOCYC:G...
# 10118      +     0  ID=cds-NP_418819.1;Parent=gene-b4402;Dbxref=Un...
# 10119      +     .  ID=gene-b4403;Dbxref=ASAP:ABE-0014442,ECOCYC:E...
# 10120      +     0  ID=cds-NP_418820.1;Parent=gene-b4403;Dbxref=Un...
#
# [5107 rows x 9 columns]

# %%
gff_data["type"].value_counts()
# Out:
# gene                      4419
# CDS                       4379
# repeat_region              697
# exon                       180
# pseudogene                 166
# tRNA                        86
# ncRNA                       72
# mobile_genetic_element      49
# sequence_feature            48
# rRNA                        22
# region                       1
# recombination_feature        1
# origin_of_replication        1
# Name: type, dtype: int64

# %%
gff_data["length"] = gff_data["end"] - gff_data["start"]

# %%
gene_data = gff_data[gff_data["type"] == "gene"]

# %%
gene_data["length"].mean()
# Out:
# 911.7795881421137

# %%
gene_data["length"].median()
# Out:
# 806.0

# %%
# %matplotlib inline

# %%
gene_data["length"].hist()

# %%
gene_data["length"].hist(bins=30, color="black")
