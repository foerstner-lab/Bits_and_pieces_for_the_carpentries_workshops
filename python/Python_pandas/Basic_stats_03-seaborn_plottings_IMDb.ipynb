# %%
import pandas as pd
import seaborn as sns

# %%
imdb = pd.read_csv("https://datasets.imdbws.com/title.ratings.tsv.gz", sep="\t")

# %%
imdb
# Out:
#             tconst  averageRating  numVotes
# 0        tt0000001            5.6      1613
# 1        tt0000002            6.0       198
# 2        tt0000003            6.5      1293
# 3        tt0000004            6.1       121
# 4        tt0000005            6.1      2068
# ...            ...            ...       ...
# 1040734  tt9916576            6.0         9
# 1040735  tt9916578            8.5        18
# 1040736  tt9916720            5.7        51
# 1040737  tt9916766            6.8        13
# 1040738  tt9916778            7.2        21
#
# [1040739 rows x 3 columns]

# %%
imdb.shape
# Out:
# (1040739, 3)

# %%
imdb.averageRating.describe()
# Out:
# count    1.040739e+06
# mean     6.877530e+00
# std      1.402329e+00
# min      1.000000e+00
# 25%      6.100000e+00
# 50%      7.100000e+00
# 75%      7.800000e+00
# max      1.000000e+01
# Name: averageRating, dtype: float64

# %%
imdb.numVotes.describe()
# Out:
# count    1.040739e+06
# mean     9.605471e+02
# std      1.587436e+04
# min      5.000000e+00
# 25%      9.000000e+00
# 50%      2.000000e+01
# 75%      7.800000e+01
# max      2.238474e+06
# Name: numVotes, dtype: float64

# %%
imdb.averageRating.hist()

# %%
imdb_subsample = imdb.sample(10000, random_state=1)

# %%
sns.stripplot(imdb_subsample.averageRating)

# %%
sns.stripplot(x=imdb_subsample.averageRating)

# %%
sns.stripplot(y=imdb_subsample.averageRating)

# %%
sns.stripplot(y=imdb_subsample.averageRating, alpha=0.1)

# %%
sns.boxplot(y=imdb_subsample.averageRating)

# %%
sns.boxenplot(y=imdb_subsample.averageRating)

# %%
sns.violinplot(y=imdb_subsample.averageRating, alpha=0.1)

# %%
sns.stripplot(y=imdb_subsample.numVotes, alpha=0.5)

# %%
imdb_subsample["voting_class"] = imdb_subsample.numVotes.apply(
    lambda rating: "more_than_20" if rating > 20 else "less_or_equal_than_20"
)

# %%
imdb_subsample
# Out:
#            tconst  averageRating  numVotes           voting_class
# 656868  tt2111050            7.8         5  less_or_equal_than_20
# 766423  tt3565390            7.4        11  less_or_equal_than_20
# 776732  tt3724934            7.9         7  less_or_equal_than_20
# 618565  tt1822388            6.8        13  less_or_equal_than_20
# 406782  tt0905027            8.0        13  less_or_equal_than_20
# ...           ...            ...       ...                    ...
# 648179  tt2051016            7.7         6  less_or_equal_than_20
# 147630  tt0246017            7.5        41           more_than_20
# 218858  tt0407706            6.4        17  less_or_equal_than_20
# 598906  tt1704593            6.8         5  less_or_equal_than_20
# 998970  tt8415876            7.8        46           more_than_20
#
# [10000 rows x 4 columns]

# %%
imdb_subsample.voting_class.value_counts()
# Out:
# less_or_equal_than_20    5191
# more_than_20             4809
# Name: voting_class, dtype: int64

# %%
sns.stripplot(imdb_subsample[imdb_subsample.voting_class == "more_than_20"].averageRating)

# %%
sns.stripplot(imdb_subsample[imdb_subsample.voting_class == "less_or_equal_than_20"].averageRating)

# %%
sns.stripplot(y=imdb_subsample.averageRating, x=imdb_subsample.voting_class)

# %%
sns.stripplot(y=imdb_subsample.averageRating, x=imdb_subsample.voting_class, alpha=0.5)

# %%
sns.violinplot(y=imdb_subsample.averageRating, x=imdb_subsample.voting_class)

# %%
sns.boxplot(y=imdb_subsample.averageRating, x=imdb_subsample.voting_class)

# %%
sns.boxenplot(y=imdb_subsample.averageRating, x=imdb_subsample.voting_class)

# %%
imdb_subsample[imdb_subsample.voting_class == "less_or_equal_than_20"].describe()
# Out:
#        averageRating     numVotes
# count    5191.000000  5191.000000
# mean        6.892429     9.985937
# std         1.429119     4.362566
# min         1.000000     5.000000
# 25%         6.100000     6.000000
# 50%         7.000000     9.000000
# 75%         7.900000    13.000000
# max        10.000000    20.000000

# %%
imdb_subsample[imdb_subsample.voting_class == "more_than_20"].describe()
# Out:
#        averageRating      numVotes
# count    4809.000000  4.809000e+03
# mean        6.883988  2.105288e+03
# std         1.347666  2.485675e+04
# min         1.000000  2.100000e+01
# 25%         6.100000  3.600000e+01
# 50%         7.100000  7.900000e+01
# 75%         7.800000  2.780000e+02
# max        10.000000  1.260227e+06
